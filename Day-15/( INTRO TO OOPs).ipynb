# %% [markdown]
# # What is Object oriented programming
# * Object-Oriented Programming (or OOP) is a paradigm of programming in which programs are written and structured around objects rather than functions or logic.

# %% [markdown]
# # What is POP VS OOP

# %% [markdown]
# ![oopstable.png](attachment:oopstable.png)

# %% [markdown]
# # Disadvantages
# - (Code maintenance)
# - (Security)
# - (Reusability)

# %% [markdown]
# ![java-oops.png](attachment:java-oops.png)

# %% [markdown]
# __Class__: In Object Oriented Programming, a Class is a blueprint for an object.
#
# **Object**: Obejct is a instance of a class which has the structure of its blueprint but also owns it unique state and behaviour

# %% [markdown]
# ![class-oops.jpg](attachment:class-oops.jpg)

# %% [markdown]
# ![images%20%281%29.jpg](attachment:images%20%281%29.jpg)

# %% [markdown]
# **Inheritance** : Inheritance is the process by which objects of one class acquires the properties of another class.

# %% [markdown]
# ![inheritance.png](attachment:inheritance.png)

# %% [markdown]
# **Polymorphism** : Ploy - many | Morphic- Forms
#    - Polymorphism meas the ability to make more forms
#    - E.g : Person change based on situation
#    * Operator overloading
#    * Method overloading

# %% [markdown]
# ![FP_2020-09-08-46.jpg](attachment:FP_2020-09-08-46.jpg)

# %% [markdown]
# **Abstraction** : Representing essential features without including background details.
#     - E.g: You will have access to car like stering, break, but you don't care about engine by person.

# %% [markdown]
# ![Car%20Driver.png](attachment:Car%20Driver.png)

# %% [markdown]
# ![Car%20Driver%20%281%29.png](attachment:Car%20Driver%20%281%29.png)
