# %% [markdown]
# ![pandas_logo.jpeg](attachment:pandas_logo.jpeg)

# %% [markdown]
# # What is pandas ?
#
# * Well pandas is open source python library that gives you excellent set of tools to do data analysis or "Data munging" so well     what is data munging  :
# * Combination of data cleaning, data manipulation, and data understanding we call it as data munging

# %% [markdown]
# # Why pandas?
# * Pandas just makes it easier to work with complex data. Because It  is builded on top of numpy. So, it is fast and efficient while doing analysis and it add more functionality and features like.

# %% [markdown]
# # Core features of pandas
# * Intelligent and Automated data alignment
# * Easy data aggregation and transformation
# * Functions to handling missing data
# * data operations
#     Grouping
#     Pivot table
# * Provides data filtration
# * Label-based slicing, fancy indexing, and subsetting of large data sets

# %% [markdown]
# # Installing pandas

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\rakes\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\rakes\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rakes\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\rakes\anaconda3\lib\site-packages (from pandas) (1.19.1)
# Requirement already satisfied: six>=1.5 in c:\users\rakes\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#Setting the path

# %%
# 'r': This is the default mode of opening a file Which opens the file for reading only. The file pointer is placed 
# at beginning of the file

# %%
company = pd.read_csv(r'C:\Users\rakes\Documents\Raq files\Data Science\Data sets\Company_Data.csv')

# %%
company
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US
# 0     Yes  Yes
# 1     Yes  Yes
# 2     Yes  Yes
# 3     Yes  Yes
# 4     Yes   No
# ..    ...  ...
# 395   Yes  Yes
# 396    No  Yes
# 397   Yes  Yes
# 398   Yes  Yes
# 399   Yes  Yes
#
# [400 rows x 10 columns]

# %%
#view

# %%
#Printing first 5 Rows
company.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
company.tail() #printing last 5 rows
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US
# 395   Yes  Yes
# 396    No  Yes
# 397   Yes  Yes
# 398   Yes  Yes
# 399   Yes  Yes

# %%
company.describe() #Describing the dataset
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
#checking complete information about the dataset
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   Age          400 non-null    int64
#  7   Education    400 non-null    int64
#  8   Urban        400 non-null    object
#  9   US           400 non-null    object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 31.4+ KB

# %%
company.shape #used to check the shape of the dataset
# Out:
# (400, 10)

# %%
company.shape[0] #printing number of rows
# Out:
# 400

# %%
company.shape[1] #printing number of columns
# Out:
# 10

# %%
lending = pd.read_excel(r'C:\Users\rakes\Documents\Raq files\Data Science\Data sets\Lending Data.xlsx')

# %%
lending.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                         NaN      NaN   -1        -2         -3
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 0              -4       -5                    -6               -7.0
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
#
#    Number .1  Unnamed: 10  Amount ($1,000).2  Number .2 CC Amount/TA1
# 0       -8.0          NaN               -9.0      -10.0           -11
# 1  3603088.0          NaN            31949.0      138.0          0.28
# 2   105081.0          NaN          3536113.0    12621.0           .
# 3   126455.0          NaN          2042267.0    10346.0             0
# 4    32973.0          NaN          5705564.0    19639.0             0

# %%
#Need to print the columns
company.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
#need to select only sales column
company['Sales']
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
company.Sales
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
#Creating a new column in existing dataset
company['Profit'] = company['Income']-company['Price']

# %%
company.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#   Urban   US  Profit
# 0   Yes  Yes     -47
# 1   Yes  Yes     -35
# 2   Yes  Yes     -45
# 3   Yes  Yes       3
# 4   Yes   No     -64

# %%
#I want to pick a sample
sample_company = company.sample(n= 100)

# %%
sample_company.head()
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 198   3.62        112      80            5         500    128   69         10
# 375   7.90        132      46            4         206    124   73         11
# 262   6.37        120      77           15          86    132   48         18
# 26    8.33        107     115           11         496    131   50         11
# 142   7.44        124      84            0         300    104   77         15
#
#     Urban   US  Profit
# 198   Yes  Yes     -48
# 375   Yes   No     -78
# 262   Yes  Yes     -55
# 26     No  Yes     -16
# 142   Yes   No     -20

# %%
sample_company.shape
# Out:
# (100, 11)

# %%
sample_company = company.sample(frac = 0.5)

# %%
sample_company.shape
# Out:
# (200, 11)

# %%
company
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US  Profit
# 0     Yes  Yes     -47
# 1     Yes  Yes     -35
# 2     Yes  Yes     -45
# 3     Yes  Yes       3
# 4     Yes   No     -64
# ..    ...  ...     ...
# 395   Yes  Yes     -20
# 396    No  Yes     -97
# 397   Yes  Yes    -133
# 398   Yes  Yes     -16
# 399   Yes  Yes     -83
#
# [400 rows x 11 columns]

# %%
#Indexing
company.iloc[:2,1]
# Out:
# 0    138
# 1    111
# Name: CompPrice, dtype: int64

# %%
company.iloc[1,2]
# Out:
# 48

# %%
company.iloc[:2,1]
# Out:
# 0    138
# 1    111
# Name: CompPrice, dtype: int64

# %%
company.iloc[:3, 6:]
# Out:
#    Age  Education Urban   US  Profit
# 0   42         17   Yes  Yes     -47
# 1   65         10   Yes  Yes     -35
# 2   59         12   Yes  Yes     -45

# %%
company.Sales.mean()
# Out:
# 7.496325000000001

# %%
company.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'Age', 'Education', 'Urban', 'US', 'Profit'],
#       dtype='object')

# %%
company.Income.min()
# Out:
# 21

# %%
company.Income.max()
# Out:
# 120

# %%
company.Advertising.max()
# Out:
# 29

# %%
company.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#   Urban   US  Profit
# 0   Yes  Yes     -47
# 1   Yes  Yes     -35
# 2   Yes  Yes     -45
# 3   Yes  Yes       3
# 4   Yes   No     -64

# %%
company.Urban.describe()
# Out:
# count     400
# unique      2
# top       Yes
# freq      282
# Name: Urban, dtype: object

# %%
company.Urban.value_counts()
# Out:
# Yes    282
# No     118
# Name: Urban, dtype: int64

# %%
company.Urban.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
company.Income.hist()
# Out:
# <AxesSubplot:>

# %%
type(company)  #DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
sales = company.Sales

# %%
type(sales) #Series is a 1D Data Structure in Pandas
# Out:
# pandas.core.series.Series

# %%
value = company.iloc[1,2]

# %%
type(value)
# Out:
# numpy.int64

# %%
company.corr() #Correlation between two parameters
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
# Profit       0.392565  -0.427526  0.778587     0.015837    0.001781 -0.670672
#
#                   Age  Education    Profit
# Sales       -0.231815  -0.051955  0.392565
# CompPrice   -0.100239   0.025197 -0.427526
# Income      -0.004670  -0.056855  0.778587
# Advertising -0.004557  -0.033594  0.015837
# Population  -0.042663  -0.106378  0.001781
# Price       -0.102177   0.011747 -0.670672
# Age          1.000000   0.006488  0.060753
# Education    0.006488   1.000000 -0.049624
# Profit       0.060753  -0.049624  1.000000

# %%
company.std()
# Out:
# Sales            2.824115
# CompPrice       15.334512
# Income          27.986037
# Advertising      6.650364
# Population     147.376436
# Price           23.676664
# Age             16.200297
# Education        2.620528
# Profit          37.668833
# dtype: float64

# %%
company.var()
# Out:
# Sales              7.975626
# CompPrice        235.147243
# Income           783.218239
# Advertising       44.227343
# Population     21719.813935
# Price            560.584436
# Age              262.449618
# Education          6.867168
# Profit          1418.940946
# dtype: float64

# %%
company.median()
# Out:
# Sales            7.49
# CompPrice      125.00
# Income          69.00
# Advertising      5.00
# Population     272.00
# Price          117.00
# Age             54.50
# Education       14.00
# Profit         -48.00
# dtype: float64

# %%
company.mode()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price   Age  Education  \
# 0    7.8      121.0    69.0          0.0         125  120.0  62.0       12.0
# 1    NaN        NaN     NaN          NaN         148  128.0   NaN       17.0
# 2    NaN        NaN     NaN          NaN         170    NaN   NaN        NaN
# 3    NaN        NaN     NaN          NaN         220    NaN   NaN        NaN
# 4    NaN        NaN     NaN          NaN         237    NaN   NaN        NaN
# 5    NaN        NaN     NaN          NaN         276    NaN   NaN        NaN
# 6    NaN        NaN     NaN          NaN         497    NaN   NaN        NaN
#
#   Urban   US  Profit
# 0   Yes  Yes   -64.0
# 1   NaN  NaN   -45.0
# 2   NaN  NaN   -26.0
# 3   NaN  NaN     NaN
# 4   NaN  NaN     NaN
# 5   NaN  NaN     NaN
# 6   NaN  NaN     NaN

# %%
lending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  96 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         94 non-null     object
#  3   TA Ratio1                    94 non-null     object
#  4   TBL Ratio1                   94 non-null     object
#  5   Amount ($1,000)              94 non-null     object
#  6   Number                       94 non-null     object
#  7   Lender Asset Size            94 non-null     object
#  8   Amount ($1,000).1            94 non-null     float64
#  9   Number .1                    94 non-null     float64
#  10  Unnamed: 10                  0 non-null      float64
#  11  Amount ($1,000).2            94 non-null     float64
#  12  Number .2                    94 non-null     float64
#  13  CC Amount/TA1                94 non-null     object
# dtypes: float64(5), object(9)
# memory usage: 10.7+ KB

# %%
lending.shape
# Out:
# (97, 14)

# %%
lending.isnull().sum()
# Out:
# Name of Lending Institution     1
# HQ State                        4
# Rank                            3
# TA Ratio1                       3
# TBL Ratio1                      3
# Amount ($1,000)                 3
# Number                          3
# Lender Asset Size               3
# Amount ($1,000).1               3
# Number .1                       3
# Unnamed: 10                    97
# Amount ($1,000).2               3
# Number .2                       3
# CC Amount/TA1                   3
# dtype: int64

# %%
lending.tail()
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
#    TBL Ratio1 Amount ($1,000) Number      Lender Asset Size  \
# 92          -               -       -  >$10B
# 93          -               -       -  >$10B
# 94        NaN             NaN     NaN                   NaN
# 95        NaN             NaN     NaN                   NaN
# 96        NaN             NaN     NaN                   NaN
#
#     Amount ($1,000).1  Number .1  Unnamed: 10  Amount ($1,000).2  Number .2  \
# 92                0.0        0.0          NaN                0.0        0.0
# 93                0.0        0.0          NaN                0.0        0.0
# 94                NaN        NaN          NaN                NaN        NaN
# 95                NaN        NaN          NaN                NaN        NaN
# 96                NaN        NaN          NaN                NaN        NaN
#
#    CC Amount/TA1
# 92           .
# 93           .
# 94           NaN
# 95           NaN
# 96           NaN

# %%
company.groupby(company.Urban).mean()
# Out:
#           Sales   CompPrice     Income  Advertising  Population       Price  \
# Urban
# No     7.563559  123.398305  67.016949     6.203390  276.677966  114.076271
# Yes    7.468191  125.634752  69.343972     6.815603  259.886525  116.514184
#
#              Age  Education     Profit
# Urban
# No     52.610169  14.033898 -47.059322
# Yes    53.620567  13.843972 -47.170213

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
import pandas as pd 
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.114888 -1.196804  2.552260 -1.799786
# 2013-01-02  1.851113  0.640202  0.600033 -0.661040
# 2013-01-03 -0.677394  0.236829 -1.402080 -0.943328
# 2013-01-04 -0.388434 -1.545116  0.063663 -0.269004
# 2013-01-05 -1.365083 -0.272412  1.977434  1.181681
# 2013-01-06  0.207021  0.238329  0.986241 -0.883547

# %%
df.loc[dates[0]]
# Out:
# A   -0.114888
# B   -1.196804
# C    2.552260
# D   -1.799786
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01 -0.114888 -1.196804
# 2013-01-02  1.851113  0.640202
# 2013-01-03 -0.677394  0.236829
# 2013-01-04 -0.388434 -1.545116
# 2013-01-05 -1.365083 -0.272412
# 2013-01-06  0.207021  0.238329

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02  1.851113  0.640202
# 2013-01-03 -0.677394  0.236829
# 2013-01-04 -0.388434 -1.545116

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  1.851113  0.640202  0.600033 -0.661040
# 2013-01-06  0.207021  0.238329  0.986241 -0.883547

# %%
company[company.Sales>8]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 5    10.81        124     113           13         501     72   78         16
# 7    11.85        136      81           15         425    120   67         10
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 387   8.67        142      73           14         238    115   73         14
# 388   8.14        135      89           11         245     78   79         16
# 389   8.44        128      42            8         328    107   35         12
# 395  12.57        138     108           17         203    128   33         14
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US  Profit
# 0     Yes  Yes     -47
# 1     Yes  Yes     -35
# 2     Yes  Yes     -45
# 5      No  Yes      41
# 7     Yes  Yes     -39
# ..    ...  ...     ...
# 387    No  Yes     -42
# 388   Yes  Yes      11
# 389   Yes  Yes     -65
# 395   Yes  Yes     -20
# 399   Yes  Yes     -83
#
# [164 rows x 11 columns]
