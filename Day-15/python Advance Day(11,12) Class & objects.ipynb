# %% [markdown]
# ![Object%20oriented%20programming.jpg](attachment:Object%20oriented%20programming.jpg)

# %% [markdown]
# # What is Class and object ?
# * __class__: In Object Oriented Programming, a Class is a blueprint for an object.
# * __object__: object is an instance of a class which has the structure of its blueprint but also owns its unique state and behaviour.

# %% [markdown]
# ## Types of variables
#
# * __class variable__: A variable that is shared by all instances of the class. class variables are not used as frequently as   instance variables are.
#
# * __Instance variable__ or attributes – data that belongs to individual objects; every object has its own copy of each one.
#
# ## Types of methods
#
# * An object has __attributes__ and __behaviours__. These behaviours are called methods in programming
# * __instance method__ These are so called because they can access unique data of their instance.
# * __class method__ Class methods don’t need self as an argument, but they do need a parameter called cls. This stands for class, and like self, gets automatically passed in by Python
# * __static methods__ This type of method takes neither a self nor a cls parameter (but of course it’s free to accept an arbitrary number of other parameters)

# %% [markdown]
# ![Copy%20of%20Simple%20Business%20Organizational%20Chart.png](attachment:Copy%20of%20Simple%20Business%20Organizational%20Chart.png)

# %% [markdown]
# # Creating class objects

# %% [markdown]
# **__init__(self) function**
#
# * All classes have a function called __init__ ()function to assign values to obeject properties, or other operations.
#
# **Self parameter**
# * The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.

# %%
class moblie:
    
    def __init__(self):
        print("I am init method")
    
    def purchase(self, name,ram):
        print(f'Thanks for purchasing {name} with {ram}')

# %%
# 1 - create an object 
# 2 - initialize the values to the instance variable
# constructor will help to create variables in one line 
# __init_() method is also called as constructor method
# while  creating a object it will check __init__() method is written if written then it will be called automatically 


john = moblie()# this step will automatically call the constructor if  __init__() method is present in class
john.brand = 'samsung'
john.ram = "8Gb"
john.purchase(john.brand, john.ram)
# Out:
# I am init method
# Thanks for purchasing samsung with 8Gb

# %% [markdown]
# ## Instance variable

# %% [markdown]
# * __Instance variable__  – instance variable is nothing but the variable belongs to object or instance called as instance variable or simply instance variable is a variable that is bound to object itself.

# %%
class mobile:
    
    def __init__(self, name, ram):
        #instance variable
        self.name = name
        self.ram = ram
        
# Creating object
m1 = mobile("oppo", "4")
print(m1.name, m1.ram)

m2 = mobile("realme", "8")
print(m2.name, m2.ram)
# Out:
# oppo 4
# realme 8

# %% [markdown]
# ## class variable:

# %% [markdown]
# * __class variable__: A variable that is shared by all instances of the class. class variables are not used as frequently as   instance variables are.

# %%
class mobile:
    
    #class variable
    Charger = "yes"
    
    def __init__(self, name, ram):
        #instance variable
        self.name = name
        self.ram = ram

print("object 1")
m1 = mobile("oppo", "4")
print(m1.name, m1.ram)
print(m1.Charger)

print("-----------------------------------")

print("object 2")
m2 = mobile("realme", "8")
print(m2.name, m2.ram)
print(mobile.Charger)
# Out:
# object 1
# oppo 4
# yes
# -----------------------------------
# object 2
# realme 8
# yes

# %% [markdown]
# ## Instance method

# %% [markdown]
# * __instance method__ Instance method belong to the Object of the class not to the class. so, they can be called after creating the Object of the class.

# %%
class mobile:
    
    #class variable
    wireless_charging = "yes"
    
    def __init__(self, name, ram):
        #instance variable
        self.name = name
        self.ram = ram
        
    #instance method     
    def display(self):
        print(f"Name :{ self.name}\nram :{self.ram}")
              

print("object 1")
m1 = mobile("oppo", "4")
print(m1.name, m1.ram)
m1.display()

print("-----------------------------------")

print("object 2")
m2 = mobile("realme", "8")
print(m2.name, m2.ram)
m2.display()
# Out:
# object 1
# oppo 4
# Name :oppo
# ram :4
# -----------------------------------
# object 2
# realme 8
# Name :realme
# ram :8

# %% [markdown]
# ## Class method

# %% [markdown]
# * __class method__ Class methods don’t need self as an argument, but they do need a parameter called cls. This stands for class, and like self, gets automatically passed in by Python

# %%
class mobile:
    
    #class variable
    wireless_charging = "yes"
    
    def __init__(self, name, ram):
        #instance variable
        self.name = name
        self.ram = ram
        
    #instance method     
    def display(self):
        print(f"Name :{ self.name}\nram :{self.ram}")
    
    @classmethod    
    def verification(cls):
        return f'Charger :{cls.wireless_charging}'
    
    
print("object 1")
m1 = mobile("oppo", "4")
print(m1.verification())
m1.display()

print("-----------------------------------")

print("object 2")
m2 = mobile("realme", "8")
print(m2.verification())
m2.display()
# Out:
# object 1
# Charger :yes
# Name :oppo
# ram :4
# -----------------------------------
# object 2
# Charger :yes
# Name :realme
# ram :8

# %% [markdown]
# ## static method

# %% [markdown]
# * __static methods__ This type of method takes neither a self nor a cls parameter (but of course it’s free to accept an arbitrary number of other parameters)
# * Note: It will be helpfull when we want to access other class objects

# %%
class mobile:
    
    #class variable
    wireless_charging = "yes"
    
    def __init__(self, name, ram):
        #instance variable
        self.name = name
        self.ram = ram
        
    #instance method     
    def display(self):
        print(f"Name :{ self.name}\nram :{self.ram}")
        
    @classmethod    
    def verification(cls):
        return f'Charger :{cls.wireless_charging}'
    
    @staticmethod
    def get_name(): 
        print("Name is correct")
            
m1 = mobile("oppo", "8")
print(mobile.wireless_charging)
print(m1.verification())
m1.get_name()
m1.display()

print("_______________________________")

m2 = mobile("realme", "4")
print(mobile.wireless_charging)
print(m2.verification())
m2.get_name()
m2.display()
# Out:
# yes
# Charger :yes
# Name is correct
# Name :oppo
# ram :8
# _______________________________
# yes
# Charger :yes
# Name is correct
# Name :realme
# ram :4

# %% [markdown]
# # Complete Variables and methods

# %%
class mobile:
    
    #class variable
    wireless_charging = "yes"
    
    def __init__(self, name, ram):
        #instance variable
        self.name = name
        self.ram = ram
        
    #instance method     
    def display(self):
        print(f"Name :{ self.name}\nram :{self.ram}")
        
    @classmethod    
    def verification(cls):
        return cls.wireless_charging
    
    @staticmethod
    def get_name(): 
        print("I am static method")
        
        
m1 = mobile("oppo", "8")
print(mobile.wireless_charging)
print(m1.verification())
m1.get_name()
m1.display()

print("_______________________________")

m2 = mobile("realme", "4")
print(mobile.wireless_charging)
print(m2.verification())
m2.get_name()
m2.display()
# Out:
# yes
# yes
# I am static method
# Name :oppo
# ram :8
# _______________________________
# yes
# yes
# I am static method
# Name :realme
# ram :4

# %% [markdown]
# # More Examples

# %%
class Student:
    
    def __init__(self,name,age, **marks):
        self.name = name 
        self.age = age 
        self.marks = marks
        
    def display(self):
        print("Name-", self.name)
        print("age- ", self.age)
        print("Marks- ", self.marks)

# %%
s1 = Student("john", 25, first=560, second=260)
s1.display()

# %%
class employees:
    
    empcount = 0 
    
    def __init__(self, Name, Salary):
        self.Name = Name
        self.Salary = Salary
        employees.empcount += 1
        
    def displayCount(self):
        print("Total Employee %d" % employees.empcount)
        
    def Displayemployee(self):
        print ("Name ", self.Name, "Salary",self.Salary)
        
emp1 = employees("Rakesh",4000)
emp2 = employees("Anuhya", 3000)
emp1.Displayemployee()
emp2.Displayemployee()
print("Total count", employees.empcount)
