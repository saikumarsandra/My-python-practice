# %% [markdown]
# # Pick your library for data visualization click link below

# %% [markdown]
# [**Scatter-plot Using Matplotlib | Seaborn | Plotly**](https://youtu.be/_oumrPc58ew)

# %% [markdown]
# [**Bar-plot with Matplotlib | Seaborn | Plotly**](https://youtu.be/T45SdKmmqCo)

# %% [markdown]
# [**Box-plot Using Matplotlib | Seaborn | Plotly**](https://youtu.be/L5kPbO1jCrg)

# %% [markdown]
# # What is matplotlib?
#
# - Matplotlib is a plotting library for python programming language and it was inatially written by john Hunter.

# %% [markdown]
# # Advantages of matplotlib
#
# * Simple and easy for beginners.
# * It has large community support and cross platform support as it is an open source tool.
# * It has full control over graphs or plot styles.
# * It can also be used in python scripts, shells, web applications servers and other graphical user interface toolkits.
# * It is fast and efficient because it is builded on numpy and scipy framework.
# * It is platform - independent and can be run on windows and macos and linux

# %% [markdown]
# # What are type of plots in matplotlib in python?
#
# * Line plot - very useful when it comes to multivariate analysis.
# * Histograms - to understand the distribution.
# * Bar charts - we can use to compare one over the other.
# * Pie charts - to present the data in percentage, ratio, proportion etc.
# * Scatterplots - to identify the relationship between two variables.
# * Subplots - Very useful when comparing two or more plots
# * Images - matplotlib can also create image with the help of imshow() funciton

# %% [markdown]
# # Installing Library

# %%
Pip install library

# %% [markdown]
# # Importing Library

# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.plot([1,2,3,4,5], [10,3,4,5,6],'r+-' ,[10,12,13,14,15],[23,24,25,26,29], 'g')

# %%
x = np.array([0, 10])
y = np.array([0, 100])

plt.plot(x, y)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 10, 12, 3])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# # Covid 19 Data

# %%
date = pd.date_range('20200501', periods=11)
day_wise_cases = [1755,2411,2487,2573,3875,2680, 3561,3390,3320,3277,4213]
Deaths = [80, 113, 125, 130,258,146,270, 230,228,243,330 ]

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %% [markdown]
# # Arguments we use for line-plot

# %%
#width, height
plt.figure(figsize=(15,8))

#set Title
plt.title()

# red color 'r'
color= 'r' #set the color

#set line style '--'
linestyle = '--' 

# set linewidth '3'
linewidth = 2.5

# set transprency
alpha = 0.5

#set axis for both x & y 
plt.axis(['x-start, x-end, y-start, y-end])
          
#set label for X axis and y - axis
plt.xlabel('Name', fontsize= 12, color = 'blue')
          
# set the limit of x & y axis
plt.xlim((10, 4000)

# set annotation 
plt.annotate('This is max till date', horizontalalignment='left',
             verticalalignment='bottom',xy= ('2020-05-11',4213),
             xytext= ('2020-05-09',4000), 
             arrowprops = dict(facecolor= 'g', shrink=0.05))
          
'max till date' #denotes annotation text 
xy= ('2020-05-11',4213) # arrow position 
xytext= ('2020-05-09',4000) # Text position
arrowprops = dict(facecolor= 'g', shrink=0.05)) # properties of arror

# %% [markdown]
# # Line plot

# %%
date = pd.date_range('20200501', periods=11)
day_wise_cases = [1755,2411,2487,2573,3875,2680, 3561,3390,3320,3277,4213]

plt.plot(date, day_wise_cases)
plt.show()

# %%
plt.plot(date, day_wise_cases)

# %%
date = pd.date_range('20200501', periods=11)
day_wise_cases = [1755,2411,2487,2573,3875,2680, 3561,3390,3320,3277,4213]

plt.style.use('classic')
#width, height in inches
plt.figure(figsize=(15,8))
plt.plot(date, day_wise_cases, color= 'r', linestyle = '--', label = 'covid-19' ,linewidth = 2.5, alpha = 0.5, marker = "^")

#title of the plot
plt.title("Positive case from 1st may 2020 to 11th may 2020", fontsize = 15)

#set x-label& y-label
plt.xlabel('Date', fontsize= 15)
plt.ylabel('Number of cases', fontsize = 15)

#set the axis
plt.axis(['2020-05-01', '2020-05-11', 1000, 5000])

# set grid
plt.grid()

# annotations
plt.annotate('This is max till date', horizontalalignment='left', verticalalignment='bottom',xy= ('2020-05-11',4213),
             xytext= ('2020-05-09',4000), arrowprops = dict(facecolor= 'g', shrink=0.05))
plt.legend()

# %% [markdown]
# # Top seven conformed covid-19  cases in india

# %%
location = ['Maharastra', 'Gujarat', 'Tamilnadu', 'Delhi', 'Rajasthan', 'Madhya Pradesh', 'Uttar pradesh']
Confirmed_cases = [23000,8500, 8000,7200,4000, 3700, 3500]

# %% [markdown]
# # Arguments for Pie Chart

# %%
explode=[0.1,0,0,0,0,0,0] #To explode specific slice

radius= 1.5 # size of the plot

autopct= '%2.1f%%' #percentage of each slice

pctdistance = 0.6 #percentage distance from the center

shadow = True #Draw a shadow beneath the pie

labeldistance= 1.1 #The radial distance at which the pie labels are drawn

counterclock= True # Specify fractions direction, clockwise or counterclockwise

# %% [markdown]
# # pie chart

# %%
location = ['Maharastra', 'Gujarat', 'Tamilnadu', 'Delhi', 'Rajasthan', 'Madhya Pradesh', 'Uttar pradesh']
Confirmed_cases = [23000,8500, 8000,7200,4000, 3700, 3500]

plt.pie(Confirmed_cases, labels= location)
plt.show()

# %%
plt.figure(figsize=(5,6))
location = ['Maharastra', 'Gujarat', 'Tamilnadu', 'Delhi', 'Rajasthan', 'Madhya Pradesh', 'Uttar pradesh']
Confirmed_cases = [23000,8500, 8000,7200,4000, 3700, 3500]

plt.style.use('tableau-colorblind10')
plt.axis('equal')

plt.pie(Confirmed_cases, labels= location, explode=[0,0.1,0,0,0,0,0],radius= 1.5, autopct= '%2.1f%%', pctdistance = 0.85,
        shadow = True, labeldistance= 1.1, counterclock= True, wedgeprops={'width': 0.5})
plt.title("Positive case from 1st may 2020 to 11th may 2020")
plt.show()

# %% [markdown]
# # Arguments for histogram

# %%
range=[1000,5000] # autoscaling is based on the specified bin range instead of the range of x

bins= 6 #set the bin size 

rwidth=0.85 #gap between the bins

color= 'r' # color

histtype{'bar', 'barstacked', 'step', 'stepfilled'}  #The type of histogram to draw

orientation{'horizontal', 'vertical'} # type of view 

align{'left', 'mid', 'right'} #Controls how the histogram is plotted default: mid

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(8,6))
plt.style.use('tableau-colorblind10')
day_wise_cases = [1755,2411,2487,2573,3875,2680, 3561,3390,3320,3277,4213]

plt.hist(day_wise_cases,range=[1000,5000], density=False, bins= 6, rwidth=0.85,
         histtype='barstacked', label= 'day_wise_cases', color= 'grey')
plt.title('Day-wise-count')
plt.xlabel('Number of cases')
plt.ylabel('counts')
plt.legend()

# %%
alpha= 0.7

linewidths=2.0

s= 100

marker = '+' 
    
# Arguments for Scatterplot
label = 'Scatter plot'

#title of the plot
plt.title("Positive-cases Vs Deaths", fontsize = 15, color = 'black')

#set x-label& y-label
plt.xlabel('day-wise-positive-cases', fontsize= 15, color = 'black')
plt.ylabel('Day-wise-death-count', fontsize = 15, color = 'black')

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,8))
day_wise_cases = [1755,2411,2487,2573,3875,2680, 3561,3390,3320,3277,4213]
Deaths = [80, 113, 125, 130,258,146,270, 230,228,243,330 ]

plt.scatter(day_wise_cases, Deaths, label = 'Scatter plot', marker = '', s= 100, linewidths=2.0, alpha= 0.7)
#title of the plot
plt.title("Positive-cases Vs Deaths", fontsize = 15, color = 'black')

#set x-label& y-label
plt.xlabel('day-wise-positive-cases', fontsize= 15, color = 'black')
plt.ylabel('Day-wise-death-count', fontsize = 15, color = 'black')

plt.legend()

# %% [markdown]
# # Arguments for boxplots

# %% [markdown]
# # Box-plot

# %%
plt.style.use('fivethirtyeight')
day_wise_cases = [1755,2411,2487,2573,3875,2680, 3561,3390,3320,3277,4213]
Deaths = [80, 113, 125, 130,258,146,270, 230,228,243,330 ]

plt.boxplot(day_wise_cases, widths=0.05 ,showmeans= True, showcaps= True, sym= 'r', whis= 1.5, vert= False, meanline= False)
plt.show()
