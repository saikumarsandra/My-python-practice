# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv( )

# %%
dataset
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  class
# 0        3  0    6      0
# ...

# %%
dataset.describe()
# Out:
#               age      gender          cp    trestbps        chol         fps  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope       class
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %%
dataset.corr()
# Out:
#                age    gender        cp  trestbps      chol       fps  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# gender   -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fps       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# class     0.222853  0.224469  0.407075  0.157754  0.070909  0.059186
#
#            restecg   thalach     exang   oldpeak     slope     class
# ...

# %%
plt.figure(figsize=(10,10))
sns.catplot(y="age" ,hue="gender", kind="count",data=dataset,edgecolor='0.5',legend=False)
plt.legend({'1= male','0= female'})
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dataset.corr(),annot=True,fmt='.2g',cmap='Set1')
plt.show()

# %%
sns.pairplot(dataset)

# %%
sns.scatterplot(data = dataset , x = 'chol',y='age',hue='cp')
plt.xlabel('Chest pain Type :1.typical angina,2.atypical angina,3.non-anginal pain,4.asymptomatic')
plt.ylabel('age')

plt.show()

# %%
sns.lineplot(data = dataset , x = 'chol',y='trestbps',hue='gender')
plt.xlabel('cholestrol')
plt.ylabel('Resting blood pressure')
plt.legend({'1= male','0= female'})
plt.show()

# %%
sns.lineplot(x="trestbps", y="age", data=dataset,ci=0)
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='age'>

# %%
sns.barplot(x='slope', y='', data=dataset)
plt.show()
